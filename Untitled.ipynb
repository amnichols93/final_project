# %%
import pandas as pd
import os
import numpy as np

# %%
rams_df2010 = pd.read_csv('Resources/Rams_Raw/rams_sportsref_download2010.csv')
rams_df2010
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        Week        Day       Date         NaN        NaN        NaN
# 1           1        Sun     12-Sep   4:15PM ET   boxscore          L
# 2           2        Sun     19-Sep   4:05PM ET   boxscore          L
# 3           3        Sun     26-Sep   4:05PM ET   boxscore          W
# 4           4        Sun      3-Oct   1:00PM ET   boxscore          W
# 5           5        Sun     10-Oct  12:56PM ET   boxscore          L
# 6           6        Sun     17-Oct   1:00PM ET   boxscore          W
# 7           7        Sun     24-Oct   1:02PM ET   boxscore          L
# 8           8        Sun     31-Oct   1:00PM ET   boxscore          W
# 9           9        NaN        NaN         NaN        NaN        NaN
# 10         10        Sun     14-Nov   4:15PM ET   boxscore          L
# 11         11        Sun     21-Nov   4:05PM ET   boxscore          L
# ...
